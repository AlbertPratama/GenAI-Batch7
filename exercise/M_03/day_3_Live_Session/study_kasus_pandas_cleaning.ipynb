# %%
import pandas as pd
import numpy as np

# %%
! pip install xlrd

# %% [markdown]
# # Data Loading

# %%
data = pd.ExcelFile('obes.xls')

# %%
data_age = data.parse(u'7.2', skiprows=4, skipfooter=14)

# %%
data_age
# Out:
#    Unnamed: 0    Total  Under 16  16-24   25-34   35-44   45-54   55-64  \
# 0         NaN      NaN       NaN    NaN     NaN     NaN     NaN     NaN
# 1     2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0
# 2     2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0
# 3     2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0
# 4     2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0
# 5     2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0
# 6     2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0
# 7     2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0
# 8     2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0
# 9     2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0
# 10    2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0
# 11    2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0
#
#     65-74  75 and over
# ...

# %%
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   11 non-null     object
#  1   Total        11 non-null     float64
#  2   Under 16     11 non-null     float64
#  3   16-24        11 non-null     float64
#  4   25-34        11 non-null     float64
#  5   35-44        11 non-null     float64
#  6   45-54        11 non-null     float64
#  7   55-64        11 non-null     float64
#  8   65-74        11 non-null     float64
#  9   75 and over  11 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# # Data Cleaning

# %%
data_age.rename(columns={'Unnamed: 0': 'Year'}, inplace=True)
data_age
# Out:
#        Year    Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# 0       NaN      NaN       NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 1   2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2   2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 3   2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 4   2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 5   2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 6   2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 7   2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 8   2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 9   2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 10  2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# ...

# %%
data_age.dropna(inplace=True, axis=0)
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 1 to 11
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         11 non-null     object
#  1   Total        11 non-null     float64
#  2   Under 16     11 non-null     float64
#  3   16-24        11 non-null     float64
#  4   25-34        11 non-null     float64
#  5   35-44        11 non-null     float64
#  6   45-54        11 non-null     float64
#  7   55-64        11 non-null     float64
#  8   65-74        11 non-null     float64
#  9   75 and over  11 non-null     float64
# dtypes: float64(9), object(1)
# memory usage: 968.0+ bytes

# %%
data_age.describe()
# Out:
#               Total    Under 16       16-24        25-34        35-44  \
# count     11.000000   11.000000   11.000000    11.000000    11.000000
# mean    6299.181818  590.454545  232.000000   788.181818  1723.454545
# std     4314.955778  108.405132  133.192342   555.484080  1215.902822
# min     1275.000000  400.000000   65.000000   136.000000   289.000000
# 25%     2299.500000  536.000000  101.500000   314.000000   562.000000
# 50%     5018.000000  579.000000  228.000000   564.000000  1469.000000
# 75%    10764.000000  644.000000  358.500000  1386.500000  2924.000000
# max    11736.000000  775.000000  391.000000  1484.000000  3277.000000
#
#              45-54        55-64       65-74  75 and over
# count    11.000000    11.000000   11.000000    11.000000
# mean   1740.454545   935.636364  227.727273    59.363636
# std    1412.783166   797.295713  185.395302    34.383929
# min     216.000000    94.000000   36.000000    20.000000
# ...

# %%
# data_age['Year'] = pd.to_datetime(data_age['Year'], format='%Y/%y').dt.year

# %%
data_age
# Out:
#        Year    Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# 1   2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2   2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 3   2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 4   2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 5   2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 6   2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 7   2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 8   2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 9   2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 10  2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 11  2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#     75 and over
# 1          23.0
# ...

# %%
data_age.set_index('Year', inplace=True)
data_age
# Out:
#            Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# Year
# 2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#          75 and over
# Year
# 2002/03         23.0
# 2003/04         24.0
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## bagaimana trend obesitas dari tahun ke tahun

# %%
data_age
# Out:
#            Total  Under 16  16-24   25-34   35-44   45-54   55-64  65-74  \
# Year
# 2002/03   1275.0     400.0   65.0   136.0   289.0   216.0    94.0   52.0
# 2003/04   1711.0     579.0   67.0   174.0   391.0   273.0   151.0   52.0
# 2004/05   2035.0     547.0  107.0   287.0   487.0   364.0   174.0   36.0
# 2005/06   2564.0     583.0   96.0   341.0   637.0   554.0   258.0   72.0
# 2006/07   3862.0     656.0  184.0   461.0  1069.0   872.0   459.0  118.0
# 2007/08   5018.0     747.0  228.0   564.0  1469.0  1198.0   598.0  157.0
# 2008/09   7988.0     775.0  322.0  1013.0  2359.0  2133.0  1099.0  221.0
# 2009/10  10571.0     632.0  361.0  1348.0  3132.0  3076.0  1555.0  378.0
# 2010/11  11574.0     525.0  375.0  1425.0  3277.0  3573.0  1820.0  456.0
# 2011/12  11736.0     495.0  391.0  1484.0  3104.0  3581.0  2119.0  468.0
# 2012/13  10957.0     556.0  356.0  1437.0  2744.0  3305.0  1965.0  495.0
#
#          75 and over
# Year
# 2002/03         23.0
# 2003/04         24.0
# ...

# %%
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 2002/03 to 2012/13
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Total        11 non-null     float64
#  1   Under 16     11 non-null     float64
#  2   16-24        11 non-null     float64
#  3   25-34        11 non-null     float64
#  4   35-44        11 non-null     float64
#  5   45-54        11 non-null     float64
#  6   55-64        11 non-null     float64
#  7   65-74        11 non-null     float64
#  8   75 and over  11 non-null     float64
# dtypes: float64(9)
# memory usage: 880.0+ bytes

# %%
data_age.loc['2002/03':'2006/07']
# Out:
#           Total  Under 16  16-24  25-34   35-44  45-54  55-64  65-74  \
# Year
# 2002/03  1275.0     400.0   65.0  136.0   289.0  216.0   94.0   52.0
# 2003/04  1711.0     579.0   67.0  174.0   391.0  273.0  151.0   52.0
# 2004/05  2035.0     547.0  107.0  287.0   487.0  364.0  174.0   36.0
# 2005/06  2564.0     583.0   96.0  341.0   637.0  554.0  258.0   72.0
# 2006/07  3862.0     656.0  184.0  461.0  1069.0  872.0  459.0  118.0
#
#          75 and over
# Year
# 2002/03         23.0
# 2003/04         24.0
# 2004/05         32.0
# 2005/06         20.0
# 2006/07         43.0

# %%
data_age.loc[2005:2012].drop('Total', axis = 1).plot()
# Out:
# <Axes: xlabel='Year'>

# %%
data_age.loc[2005:2012]['Under 16'].plot(label="Under 16", legend=True)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # time

# %%
date_rng = pd.date_range(start='1/01/2020', end='1/08/2020', freq='H')

# %%
date_rng
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                ...
#                '2020-01-07 15:00:00', '2020-01-07 16:00:00',
#                '2020-01-07 17:00:00', '2020-01-07 18:00:00',
#                '2020-01-07 19:00:00', '2020-01-07 20:00:00',
#                '2020-01-07 21:00:00', '2020-01-07 22:00:00',
#                '2020-01-07 23:00:00', '2020-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0,100,size=(len(date_rng)))
df
# Out:
#                    date  data
# 0   2020-01-01 00:00:00    41
# 1   2020-01-01 01:00:00    47
# 2   2020-01-01 02:00:00    63
# 3   2020-01-01 03:00:00     2
# 4   2020-01-01 04:00:00     5
# ..                  ...   ...
# 164 2020-01-07 20:00:00    81
# 165 2020-01-07 21:00:00    62
# 166 2020-01-07 22:00:00    89
# 167 2020-01-07 23:00:00    40
# 168 2020-01-08 00:00:00    72
#
# [169 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    169 non-null    datetime64[ns]
#  1   data    169 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.8 KB

# %%
df.set_index('date', inplace=True)

# %%
pd.to_datetime('2020-01-07 08:00:00', format='%Y-%m-%d %H:%M:%S')
# Out:
# Timestamp('2020-01-07 08:00:00')

# %%
from datetime import datetime
string_date_rng_2 = ['June-01-2020', 'June-02-2020', 'June-03-2020']
timestamp_date_rng_2 = [datetime.strptime(x,'%B-%d-%Y') for x in string_date_rng_2]

# %% [markdown]
# # Data Cleaning Process

# %% [markdown]
# 1. Cek Data (baris, kolom, isi)
# 2. Pahami tipe dan arti dari tiap kolom
# 3. Cek Tipe data (apakah sudah sesuai ekspektasi)
# 4. Cek missing values (standard)
# 5. Cek non standard (ada atau tidak)
# 6. Cek invalid dengan describe/ unique
# 7. Cek data duplicates (mau diinclude atau tidak) (untuk machine learning drop)
# 8. Sesuaikan Tipe data
# 9. Fill/drop missing dst
